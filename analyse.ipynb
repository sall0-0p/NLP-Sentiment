# %% [markdown]
# ## SENTIMENT ANALYSIS

# %% [markdown]
# #### IMPORT LIBRARIES

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %% [markdown]
# #### Read opinions from CSV file

# %%
opinions = pd.read_csv('./consolidated_opinions.csv', encoding='UTF-8')

# %%
opinions = opinions[['opinion', 'score', 'sentiment']]

# %%
opinions.sentiment = opinions.sentiment.str.lower()

# %%
sa = SentimentIntensityAnalyzer()
opinions['vader'] = opinions.opinion.apply(lambda o: sa.polarity_scores(o))

# %%
opinions
# Out:
#                                                 opinion  score sentiment  \
# 0     Great experience playing Racing Thunder 3, enj...    4.0  positive
# 1     Great experience playing Mystic Realms Online,...    4.0  positive
# 2     Great experience playing CyberStrike Arena, en...    4.0  positive
# 3     Great experience playing Farm Life Simulator, ...    4.0  positive
# 4     Great experience playing Galaxy Quest IV, enjo...    4.0  positive
# ...                                                 ...    ...       ...
# 4795  Too complex for its own good. Late game lag is...    2.0  negative
# 4796                   1945 runs at 1 frame per minute.    2.0  negative
# 4797  1000 hours in and I'm just getting started. Th...    4.0  positive
# 4798         Game crashed, opened it again immediately.    4.0  positive
# 4799  Paid $40 to stare at a map for 5 hours. Would ...    5.0  positive
#
#                                                   vader
# 0     {'neg': 0.0, 'neu': 0.443, 'pos': 0.557, 'comp...
# 1     {'neg': 0.0, 'neu': 0.443, 'pos': 0.557, 'comp...
# 2     {'neg': 0.0, 'neu': 0.405, 'pos': 0.595, 'comp...
# 3     {'neg': 0.0, 'neu': 0.443, 'pos': 0.557, 'comp...
# 4     {'neg': 0.0, 'neu': 0.443, 'pos': 0.557, 'comp...
# ...                                                 ...
# 4795  {'neg': 0.218, 'neu': 0.648, 'pos': 0.134, 'co...
# 4796  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4797  {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'comp...
# 4798  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4799  {'neg': 0.054, 'neu': 0.846, 'pos': 0.1, 'comp...
#
# [4800 rows x 4 columns]
